# %% [markdown]
# <a href="https://colab.research.google.com/github/tb-harris/neuroscience-2024/blob/main/11_Visualizing_Neurons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install neurom
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.1/110.1 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 7.8 MB/s eta 0:00:00
# ...

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')

import neurom as nm
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
reconstruction_files = pd.read_hdf('/content/drive/Shareddrives/Lisman Laboratory/Lisman 2024/Neuro/Data/raw_data/reconstruction_paths.hdf')

# %%
neuron_file = reconstruction_files[862596299]

# %%
m = nm.load_morphology(neuron_file)

# %%
from neurom.view import plot_morph, plot_morph3d, plot_dendrogram

# %%
plot_morph(m)

# %%
plot_morph3d(m)

# %%
plot_dendrogram(m)
